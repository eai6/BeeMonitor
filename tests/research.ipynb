# %%
from beemonitor import BeeMonitor

# %%
# Complete end-to-end analysis!
monitor = BeeMonitor()

# %%
import torch
# Check for MPS availability and set the device
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("Using MPS device (GPU) for acceleration")
else:
    device = torch.device("cpu")
    print("MPS not available, using CPU")

# Load your model and send it to the selected device
from ultralytics import YOLO
model = YOLO("/Users/edwardamoah/Documents/GitHub/BeeMonitor_eai6/models/bee_tracking_back_up_Full_Mode.pt") # Example model
model.to(device)

# Now you can train or run inference
# Example for training:
# model.train(data="coco8.yaml", epochs=100, device=device)
# Example for inference:
# results = model.predict(source="your_image.jpg", device=device)
# Out:
# Using MPS device (GPU) for acceleration
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
# ...

# %%
import os
import pandas as pd

# %%
import json

#input_folder = "/Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel"
input_folder = "/Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Natalie/beeHotel"
#input_folder = "/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos"
folders = os.listdir(input_folder)
#folders = ["/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos"]
files = []
for folder in folders:
    folder_path = os.path.join(input_folder, folder)
    for file in os.listdir(folder_path):
        if file.endswith(".mp4"):
            files.append(os.path.join(folder_path, file))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 6
#       4 input_folder = "/Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Natalie/beeHotel"
#       5 #input_folder = "/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos"
# ----> 6 folders = os.listdir(input_folder)
#       7 #folders = ["/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos"]
#       8 files = []
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Natalie/beeHotel'

# %%
files
# Out:
# ['/Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Natalie/beeHotel/2024-05-10/2024-05-10_08_01_29.mp4',
#  '/Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Natalie/beeHotel/2024-05-10/2024-05-10_08_10_00.mp4',
#  '/Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Natalie/beeHotel/2024-05-10/2024-05-10_08_20_01.mp4',
#  '/Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Natalie/beeHotel/2024-05-10/2024-05-10_08_30_00.mp4',
#  '/Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Natalie/beeHotel/2024-05-10/2024-05-10_08_40_00.mp4',
#  '/Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Natalie/beeHotel/2024-05-10/2024-05-10_08_50_00.mp4',
#  '/Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Natalie/beeHotel/2024-05-10/2024-05-10_09_00_01.mp4',
#  '/Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Natalie/beeHotel/2024-05-10/2024-05-10_09_10_00.mp4',
#  '/Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Natalie/beeHotel/2024-05-10/2024-05-10_09_20_00.mp4',
#  '/Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Natalie/beeHotel/2024-05-10/2024-05-10_09_30_00.mp4',
# ...

# %%
# id = ["2024-05-16_18_00_00", "2024-05-11_11_00_00", "2024-05-11_10_50_00", "2024-05-30_18_40_00"]
# def isInID(file):
#     for i in id:
#         if i in file:
#             return True
#     return False
# files = [f for f in files if isInID(f)]
# files

# %%
failed_files = []
for file in files:
    try:
        print(f"Processing video: {file}")
        nest = monitor.get_nest_detections(file)
        #nest.to_csv(output_folder
        if nest is None:
            #print(f"No nest detections for video: {file}")
            failed_files.append(file)
            continue
    except Exception as e:
        print(f"Error processing video {file}: {e}")
    

# output_folder = monitor.config.output.base_folder
# for file in os.listdir(input_folder):
#     if file.endswith(".mp4"):
#         try:
#             video_path = os.path.join(input_folder, file)
#             print(f"Processing video: {video_path}")
#             nest = monitor.get_nest_detection(video_path)
#             #nest.to_csv(output_folder+f"/{file.replace('.mp4', '_nest_detection.csv')}")

#             # nests = monitor.process_nest_detection(file, nest)
#             # # nests is a dictionary with nest IDs as keys and DataFrames as values, so save as json
#             # out_path = os.path.join(output_folder, file.replace('.mp4', '_nests.json'))
#             # #nests_serializable = {str(k): v.to_dict(orient='records') for k, v in nests.items()}
#             # with open(out_path, "w") as f:
#             #     json.dump(nests, f, indent=2)
#             # print(f"Saved nests JSON to: {out_path}")
#         except Exception as e:
#             print(f"Error processing video {video_path}: {e}")

# %%
# # Only show blob rejection logs (filter out other debug messages)
# import logging

# class BlobFilterOnly(logging.Filter):
#     def filter(self, record):
#         return 'Blob REJECTED' in record.getMessage() or 'Blob extraction summary' in record.getMessage()

# logger = logging.getLogger('beemonitor.core.motion_tracking')
# logger.setLevel(logging.DEBUG)
# logger.addFilter(BlobFilterOnly())

# %%
from beemonitor import BeeMonitor
from beemonitor.core.config import Config
input_folder = "/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos/site_mendels"

config = Config.default()
config.video.debug_mode = True
config.video.annotation_mode = True
config.tracking.debug_mode = True
monitor = BeeMonitor(config=config)

# %%
import os
folder = "/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos/mendels_2025/evaluation_data/"
files = [os.path.join(folder, f) for f in os.listdir(folder) if f.endswith(".mp4")]
video_file = files[6]
#/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos/mendels_2025/short_videos/short_output/synthesized_mendels_2024-05-23_18_20_25.mp4
#video_file = "/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos/mendels_2025/short_videos/mendels_2024-05-08_15_57_03.mp4"
#video_file = "/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos/mendels_2025/short_videos/mendels_2024-05-23_18_20_25.mp4"
#video_file = "/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos/mendels_2025/short_videos/mendels_2024-05-23_18_20_25.mp4"
# video_file ="/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos/mendels_2025/short_videos/site_2024-05-08_11_24_10.mp4"
#video_file = "/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos/mendels_2025/poster_videos/mendels_2024-04-30_09_00_00.mp4"
video_file = "/Users/edwardamoah/Documents/GitHub/BeeVision/Experiments/CVPR_Evaluation_Video_Data/mendels_2024-04-30_09_00_00.mp4"
output_folder = "/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos/mendels_2025/poster_videos"
result = monitor.analyze_video(video_file, visualize=True, output_folder=output_folder)
result.to_csv(output_folder=output_folder)
result.save_video(output_folder=output_folder)
# Out:
# ÃƒÂ¢Ã…Â¡Ã‚Â ÃƒÂ¯Ã‚Â¸Ã‚Â DL detection at (np.float32(800.94635), np.float32(110.69273)) blocked by track 1 (dist=3.9px) - possible stationary track issue!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 13
#      11 video_file = "/Users/edwardamoah/Documents/GitHub/BeeVision/Experiments/CVPR_Evaluation_Video_Data/mendels_2024-04-30_09_00_00.mp4"
#      12 output_folder = "/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos/mendels_2025/poster_videos"
# ---> 13 result = monitor.analyze_video(video_file, visualize=True, output_folder=output_folder)
#      14 result.to_csv(output_folder=output_folder)
#      15 result.save_video(output_folder=output_folder)
#
# File ~/Documents/GitHub/BeeMonitor/src/beemonitor/core/video_analyzer.py:1226, in BeeMonitor.analyze_video(self, video_path, nest_video_path, output_folder, visualize)
# ...

# %%
# analyze videos in a folder
input_folder = "/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos/mendels_2025/short_videos"
output_folder = "/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos/mendels_2025/short_videos/new_output"
results = monitor.analyze_videos_in_folder(
    video_folder=input_folder,
    visualize=True,
    output_folder=output_folder,
    max_workers=5
)

# save results which is dictionary of video filename to AnalysisResults
for video_file, analysis_results in results.items():
    try:
        if analysis_results is not None:
            analysis_results.to_csv(output_folder=output_folder)
            analysis_results.save_video(output_folder=output_folder)
        else:
            print(f"No analysis results for video: {video_file}")
    except Exception as e:
        print(f"Error saving results for video {video_file}: {e}")
# Out:
# Ultralytics 8.3.223 🚀 Python-3.12.5 torch-2.9.0 CPU (Apple M3 Pro)
# Ultralytics 8.3.223 🚀 Python-3.12.5 torch-2.9.0 CPU (Apple M3 Pro)
# Ultralytics 8.3.223 🚀 Python-3.12.5 torch-2.9.0 CPU (Apple M3 Pro)
# Ultralytics 8.3.223 🚀 Python-3.12.5 torch-2.9.0 CPU (Apple M3 Pro)
# YOLOv12m summary (fused): 169 layers, 20,106,454 parameters, 0 gradients, 67.1 GFLOPs
# YOLOv12m summary (fused): 169 layers, 20,106,454 parameters, 0 gradients, 67.1 GFLOPs
# YOLOv12m summary (fused): 169 layers, 20,106,454 parameters, 0 gradients, 67.1 GFLOPs
# YOLOv12m summary (fused): 169 layers, 20,106,454 parameters, 0 gradients, 67.1 GFLOPs
# Quality check failed: Expected 60 nests (±3), got 50
# Attempt 1: Quality check failed
# Quality check failed: Expected 60 nests (±3), got 49
# Attempt 2: Quality check failed
# Ultralytics 8.3.223 🚀 Python-3.12.5 torch-2.9.0 CPU (Apple M3 Pro)
# Ultralytics 8.3.223 🚀 Python-3.12.5 torch-2.9.0 CPU (Apple M3 Pro)
# ...

# %%
# analyze videos in a folder
input_folder = "/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos/mendels_2025/short_videos"
output_folder = "/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos/mendels_2025/short_videos/short_output"
results = monitor.analyze_videos_in_folder(
    video_folder=input_folder,
    visualize=True,
    output_folder=output_folder,
    max_workers=5

)

# save results which is dictionary of video filename to AnalysisResults
for video_file, analysis_results in results.items():
    try:
        if analysis_results is not None:
            analysis_results.to_csv(output_folder=output_folder)
            analysis_results.save_video(output_folder=output_folder)
        else:
            print(f"No analysis results for video: {video_file}")
    except Exception as e:
        print(f"Error saving results for video {video_file}: {e}")
# Out:
# Ultralytics 8.3.223 🚀 Python-3.12.5 torch-2.9.0 CPU (Apple M3 Pro)
# Ultralytics 8.3.223 🚀 Python-3.12.5 torch-2.9.0 CPU (Apple M3 Pro)
# Ultralytics 8.3.223 🚀 Python-3.12.5 torch-2.9.0 CPU (Apple M3 Pro)
# Ultralytics 8.3.223 🚀 Python-3.12.5 torch-2.9.0 CPU (Apple M3 Pro)
# YOLOv12m summary (fused): 169 layers, 20,106,454 parameters, 0 gradients, 67.1 GFLOPs
# YOLOv12m summary (fused): 169 layers, 20,106,454 parameters, 0 gradients, 67.1 GFLOPs
# YOLOv12m summary (fused): 169 layers, 20,106,454 parameters, 0 gradients, 67.1 GFLOPs
# YOLOv12m summary (fused): 169 layers, 20,106,454 parameters, 0 gradients, 67.1 GFLOPs
# Quality check failed: Expected 60 nests (±3), got 50
# Attempt 1: Quality check failed
# Ultralytics 8.3.223 🚀 Python-3.12.5 torch-2.9.0 CPU (Apple M3 Pro)
# YOLOv12m summary (fused): 169 layers, 20,105,683 parameters, 0 gradients, 67.1 GFLOPs
# Quality check failed: Expected 60 nests (±3), got 49
# Attempt 2: Quality check failed
# ...

# %%
# analyze videos in a folder
input_folder = "/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos/mendels_2025/evaluation_data/Analyzed_videos"
output_folder = "/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos/mendels_2025/evaluation_data/Analyzed_videos/output"
results1 = monitor.analyze_videos_in_folder(
    video_folder=input_folder,
    visualize=False,
    output_folder=output_folder,
    max_workers=5
)

# save results which is dictionary of video filename to AnalysisResults
for video_file, analysis_results in results1.items():
    try:
        if analysis_results is not None:
            analysis_results.to_csv(output_folder=output_folder)
            analysis_results.save_video(output_folder=output_folder)
        else:
            print(f"No analysis results for video: {video_file}")
    except Exception as e:
        print(f"Error saving results for video {video_file}: {e}")

# %%
results['/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos/mendels_2025/evaluation_data/Analyzed_videos/sample/mendels_2025-04-21_17_10_00.mp4']
# Out:
# AnalysisResults(events=37, tracks=22, nests=60)

# %%
input_folder = "/Users/edwardamoah/Documents/GitHub/BeeVision/Experiments/CVPR_Evaluation_Video_Data"


output_folder = "/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos/mendels_2025/CVPR_output"
# analyze videos in a folder
results1 = monitor.analyze_videos_in_folder(input_folder, output_folder=output_folder, visualize=True, max_workers=8)


# save events results which is dictionary of video filename to AnalysisResults
for video_file, analysis_results in results1.items():
    try:
        if analysis_results is not None:
            analysis_results.to_csv(output_folder=output_folder)
            analysis_results.save_video(output_folder=output_folder)
        else:
            print(f"No analysis results for video: {video_file}")
    except Exception as e:
        print(f"Error saving results for video {video_file}: {e}")
# Out:
# ÃƒÂ¢Ã…Â¡Ã‚Â ÃƒÂ¯Ã‚Â¸Ã‚Â DL detection at (np.float32(390.2076), np.float32(305.92432)) blocked by track 0 (dist=3.5px) - possible stationary track issue!
# ÃƒÂ¢Ã…Â¡Ã‚Â ÃƒÂ¯Ã‚Â¸Ã‚Â DL detection at (np.float32(921.90625), np.float32(562.77277)) blocked by track 1 (dist=8.4px) - possible stationary track issue!
# ÃƒÂ¢Ã…Â¡Ã‚Â ÃƒÂ¯Ã‚Â¸Ã‚Â DL detection at (np.float32(922.7987), np.float32(583.9923)) blocked by track 1 (dist=29.1px) - possible stationary track issue!
# ÃƒÂ¢Ã…Â¡Ã‚Â ÃƒÂ¯Ã‚Â¸Ã‚Â DL detection at (np.float32(932.7739), np.float32(603.4838)) blocked by track 1 (dist=49.0px) - possible stationary track issue!
# ÃƒÂ¢Ã…Â¡Ã‚Â ÃƒÂ¯Ã‚Â¸Ã‚Â DL detection at (np.float32(978.11475), np.float32(627.42993)) blocked by track 2 (dist=26.2px) - possible stationary track issue!
# ÃƒÂ¢Ã…Â¡Ã‚Â ÃƒÂ¯Ã‚Â¸Ã‚Â DL detection at (np.float32(1007.2618), np.float32(630.708)) blocked by track 2 (dist=55.0px) - possible stationary track issue!
# ...

# %%
# save the dictionary objects of all the results as JSON (handles Timestamps/numpy types)
import json
import numpy as np
import datetime
import pandas as pd
import os

def to_serializable(o):
    if isinstance(o, pd.DataFrame):
        return o.to_dict(orient='records')
    if isinstance(o, dict):
        return {str(k): to_serializable(v) for k, v in o.items()}
    if isinstance(o, (list, tuple, set)):
        return [to_serializable(x) for x in o]
    if isinstance(o, np.ndarray):
        return to_serializable(o.tolist())
    if isinstance(o, (np.integer,)):
        return int(o)
    if isinstance(o, (np.floating,)):
        return float(o)
    if isinstance(o, (pd.Timestamp, datetime.datetime)):
        return o.isoformat()
    if hasattr(o, "to_dict") and not isinstance(o, (str, bytes)):
        try:
            return to_serializable(o.to_dict())
        except Exception:
            return str(o)
    try:
        json.dumps(o)
        return o
    except Exception:
        return str(o)

def _json_default(o):
    # fallback for json.dump in case something slipped through
    if isinstance(o, (pd.Timestamp, datetime.datetime)):
        return o.isoformat()
    if isinstance(o, np.integer):
        return int(o)
    if isinstance(o, np.floating):
        return float(o)
    if isinstance(o, np.ndarray):
        return o.tolist()
    if hasattr(o, "to_dict"):
        try:
            return o.to_dict()
        except Exception:
            return str(o)
    return str(o)

results_serializable = {}
for video_path, analysis_results in results1.items():
    if analysis_results is None:
        continue
    key = os.path.basename(video_path)
    obj = analysis_results.to_dict() if hasattr(analysis_results, "to_dict") else analysis_results
    results_serializable[key] = to_serializable(obj)

# with open("cvpr_evaluation_results_v3.json", "w") as f:
#     json.dump(results_serializable, f, indent=2, default=_json_default)


with open("cvpr_evaluation_results_v7_medium.json", "w") as f:
    json.dump(results_serializable, f, indent=2, default=_json_default)

# %%
# results_serializable = {}
# for video_path, analysis_results in results.items():
#     if analysis_results is None:
#         continue
#     key = os.path.basename(video_path)
#     obj = analysis_results.to_dict() if hasattr(analysis_results, "to_dict") else analysis_results
#     results_serializable[key] = to_serializable(obj)

# with open("additional_evaluation_results_v4.json", "w") as f:
#     json.dump(results_serializable, f, indent=2, default=_json_default)

# %%
# get all events from results1
import pandas as pd
import os
def getAllEvents(results):
    df_events = pd.DataFrame()
    for video_file, analysis_results in results.items():
        print(video_file)
        print(os.path.basename(video_file))
        if analysis_results is not None:
            df_events_temp = analysis_results.events.copy()
            df_events_temp['filename'] = video_file
            df_events_temp['video'] = os.path.basename(video_file)
            df_events = pd.concat([df_events, df_events_temp], ignore_index=True)
    return df_events

# %%
csv = getAllEvents(results=results1)
# Out:
# /Users/edwardamoah/Documents/GitHub/BeeVision/Experiments/CVPR_Evaluation_Video_Data/mendels_2024-05-23_12_00_00.mp4
# mendels_2024-05-23_12_00_00.mp4
# /Users/edwardamoah/Documents/GitHub/BeeVision/Experiments/CVPR_Evaluation_Video_Data/mendels_2024-04-30_09_20_00.mp4
# mendels_2024-04-30_09_20_00.mp4
# /Users/edwardamoah/Documents/GitHub/BeeVision/Experiments/CVPR_Evaluation_Video_Data/mendels_2024-04-30_09_10_01.mp4
# mendels_2024-04-30_09_10_01.mp4
# /Users/edwardamoah/Documents/GitHub/BeeVision/Experiments/CVPR_Evaluation_Video_Data/mendels_2024-05-23_12_40_00.mp4
# mendels_2024-05-23_12_40_00.mp4
# /Users/edwardamoah/Documents/GitHub/BeeVision/Experiments/CVPR_Evaluation_Video_Data/mendels_2024-05-08_15_30_00.mp4
# mendels_2024-05-08_15_30_00.mp4
# /Users/edwardamoah/Documents/GitHub/BeeVision/Experiments/CVPR_Evaluation_Video_Data/mendels_2024-05-08_15_00_00.mp4
# mendels_2024-05-08_15_00_00.mp4
# ...

# %%
csv.to_csv("CVPR_Evaluation_Results_v7.csv")

# %%
[result]
# Out:
# [AnalysisResults(events=13, tracks=44, nests=60)]

# %%
csv = result.events

# %%
csv['filename'] = video_file
csv['video'] = os.path.basename(video_file)

# %%
csv.to_csv("CVPR_Evaluation_Results_v6.csv")

# %%
from typing import List
import numpy as np

def _create_composite_frame(self, frames: List[np.ndarray]) -> np.ndarray:
    """Create max composite from frame buffer for motion detection."""
    if not frames:
        return None
    return np.maximum.reduce(frames)

# %%
video_file
# Out:
# '/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos/mendels_2025/short_videos/site_2024-05-08_11_24_10.mp4'

# %%
import cv2 as cv

# %%
cap = cv.VideoCapture(video_file)

# %%
buffer = []
while True:
    ret, frame = cap.read()
    if not ret:
        break
    buffer.append(frame)
    if len(buffer) == 10:
        composite_frame = np.maximum.reduce(buffer)
        cv.imshow("Composite Frame", composite_frame)
        cv.waitKey(0)
        buffer = []
cap.release()
cv.destroyAllWindows()
